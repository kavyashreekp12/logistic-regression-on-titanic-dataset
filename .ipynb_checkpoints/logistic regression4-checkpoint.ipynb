# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
titanic_data=pd.read_csv('train_clean.csv')
titanic_data.sample(5)
# Out:
#       Age Cabin Embarked     Fare                             Name  Parch  \
# 11   58.0  C103        S  26.5500         Bonnell, Miss. Elizabeth      0
# 547  30.0   NaN        C  13.8625       Padro y Manent, Mr. Julian      0
# 227  20.5   NaN        S   7.2500  Lovell, Mr. John Hall ("Henry")      0
# 448   5.0   NaN        C  19.2583   Baclini, Miss. Marie Catherine      1
# 339  45.0     T        S  35.5000     Blackwell, Mr. Stephen Weart      0
#
#      PassengerId  Pclass     Sex  SibSp  Survived         Ticket Title  \
# 11            12       1  female      0         1         113783  Miss
# 547          548       2    male      0         1  SC/PARIS 2146    Mr
# 227          228       3    male      0         0      A/5 21173    Mr
# 448          449       3  female      2         1           2666  Miss
# 339          340       1    male      0         0         113784    Mr
#
#      Family_Size
# 11             0
# 547            0
# 227            0
# 448            3
# 339            0

# %%
print('Passenger count = ',len(titanic_data.index))
# Out:
# Passenger count =  891
